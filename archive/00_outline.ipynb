# %% [markdown]
# # Capstone Project Outline

# %% [markdown]
# ## Problem Statement:
#
# The goal of this project is to evaluate favorability of sites in California for rooftop solar power development. The assessment is focused by county and integrates the existing power infrastructure (type, age, capacity), power demand, power cost, and potentially developable rooftop area in order to identify regions with the most available market development.
#
# ## Background
#
# Electrical power generation in the state of California comes from a patchwork of predominantly natural gas, hydro, and renewable energy power as well as a single nuclear powerplant (Diablo Canyon) and a few large out of state sources (Columbia River hydro, Utah coal plants, etc).  Rooftop solar power generation is favorable because it is moular and can be easily installed within the demand environment (in town).  This cuts down on transmission costs and also boosts the contribution from renewables, particularly important in California where the greenhouse emissions standards are some the most strict in the country.
#
# | Fuel Type | In-State Generation (GWh) |  In-State Generation (%) | NW Imports (GWh) | SW Imports (GWh) | Energy Mix (GWh) | Power Mix (%) |
# | - | - | - | - | - | - | - |
# | Coal | 294 | 0.15% | 399 | 8,740 | 9,433 | 3.30% |
# | Large Hydro | 22,096 | 11.34% | 7,418 | 985 | 30,499 | 10.68% |
# | Natural Gas | 90,691 | 46.54% | 49 | 8,904 | 99,644 | 34.91% |
# | Nuclear | 18,268 | 9.38% | 0 | 7,573 | 25,841 | 9.05% |
# | Oil | 35 | 0.02% | 0 | 0 | 35 | 0.01% |
# | Other | 430 | 0.22% | 0 | 9 | 439 | 0.15% |
# | Renewables | 63,028 | 32.35% | 14,074 | 12,400 | 89,502 | 31.36% |
# | Biomass | 5,909 | 3.03% | 772 | 26 | 6,707 | 2.35% |
# | Geothermal | 11,528 | 5.92% | 171 | 1,269 | 12,968 | 4.54% |
# | Small Hydro | 4,248 | 2.18% | 334 | 1 | 4,583 | 1.61% |
# | Solar | 27,265 | 13.99% | 174 | 5,094 | 32,533 | 11.40% |
# | Wind | 14,078 | 7.23% | 12,623 | 6,010 | 32,711 | 11.46% |
# | Unspecified | N/A | N/A | 17,576 | 12,519 | 30,095 | 10.54% |
# | Total | 194,842 | 100.00% | 39,517 | 51,130 | 285,488 | 100.00% |
#
# **Other:** Petroleum Coke/Waste Heat

# %% [markdown]
# ## Methods
# - Step 1:  integrate existing data to identify regions with production/consumption mismatch, outdated infrastructure, high cost
# - Step 2:  forecast trends in energy production, forecast changes in population, changes in cost
#
# **Target Output**
# - 1 row for each county
# - Ranking of solar development favorability from 0-100
#
# **Concern**
# - Not really running a model here, more of a classification
# - Might be a clustering evaluation?
#
# ## Data
#
# **Step 1**
# - power plant database:  location, age, capacity **(located, working on access)**
# - demand by county **(in hand)**
# - electricity cost by county **(derived from utilities map or openei doc)**
# - developable rooftop capacity by county **(in hand)**
#
# **Step 2**
# - openei production history **(in hand)**
# - 2010, 2020 census data by county **(in hand)**
# - Dark sky weather archive **(scraper built)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Powerplant Database:  PRODUCTION
#
# - I can estimate power production totals, breakdown, and infrastructure age from this data
# - One drawback is that it only goes up to 2014
# - I have a lot more EDA to do on this front

# %%
power_plants = pd.read_csv('datasets/power_plants_01-14.csv')
power_plants.head().T
# Out:
#                                                                    0  \
# Plant Type Code                                                    C
# RPS Eligible                                                   False
# Primary Fuel Type                                               Coal
# Solar Thermal                                                  False
# Small Hydro                                                    False
# CEC Plant ID                                                   C0001
# EIA Plant ID                                                   10002
# Plant Name         ACE Cogeneration (ACE is Argus Cogen Expansion...
# Unit                                                           GEN 1
# State                                                             CA
# County                                                San Bernardino
# City                                                           Trona
# Start Date                                                12/01/1990
# Retire Date                                               10/01/2014
# 2014                                                             NaN
# 2013                                                          108.0
# 2012                                                          108.0
# 2011                                                          108.0
# 2010                                                          108.0
# 2009                                                          108.0
# 2008                                                          108.0
# 2007                                                          108.0
# 2006                                                          108.0
# 2005                                                          108.0
# 2004                                                          108.0
# 2003                                                          108.0
# 2002                                                          108.0
# 2001                                                          108.0
#
#                                                  1  \
# Plant Type Code                                  C
# RPS Eligible                                 False
# Primary Fuel Type                             Coal
# Solar Thermal                                False
# Small Hydro                                  False
# CEC Plant ID                                 C0002
# EIA Plant ID                                 10601
# Plant Name         Los Angeles Refinery - Calciner
# Unit                                        UNIT 1
# State                                           CA
# County                                 Los Angeles
# City                                    Wilmington
# Start Date                              12/01/1982
# Retire Date                                    NaN
# 2014                                         35.8
# 2013                                         35.8
# 2012                                         35.8
# 2011                                         35.8
# 2010                                         35.8
# 2009                                         35.8
# 2008                                         35.8
# 2007                                         35.8
# 2006                                         35.8
# 2005                                         35.8
# 2004                                         35.8
# 2003                                         35.8
# 2002                                         35.8
# 2001                                         35.8
#
#                                                                    2  \
# Plant Type Code                                                    C
# RPS Eligible                                                   False
# Primary Fuel Type                                               Coal
# Solar Thermal                                                  False
# Small Hydro                                                    False
# CEC Plant ID                                                   C0004
# EIA Plant ID                                                   54238
# Plant Name         Port of Stockton District Energy Facility - Re...
# Unit                                                           GEN 1
# State                                                             CA
# County                                                   San Joaquin
# City                                                        Stockton
# Start Date                                                12/01/1989
# Retire Date                                               01/01/2011
# 2014                                                             NaN
# 2013                                                             NaN
# 2012                                                             NaN
# 2011                                                             NaN
# 2010                                                           49.9
# 2009                                                           49.9
# 2008                                                           49.9
# 2007                                                           49.9
# 2006                                                           49.9
# 2005                                                           49.9
# 2004                                                           49.9
# 2003                                                           49.9
# 2002                                                           49.9
# 2001                                                           49.9
#
#                                                                    3  \
# Plant Type Code                                                    C
# RPS Eligible                                                   False
# Primary Fuel Type                                               Coal
# Solar Thermal                                                  False
# Small Hydro                                                    False
# CEC Plant ID                                                   C0005
# EIA Plant ID                                                   56446
# Plant Name         Buena Vista Biomass Power (Jackson Valley) Ret...
# Unit                                                               1
# State                                                             CA
# County                                                        Amador
# City                                                            Ione
# Start Date                                                06/01/1986
# Retire Date                                               12/31/2012
# 2014                                                             NaN
# 2013                                                             NaN
# 2012                                                             NaN
# 2011                                                           18.4
# 2010                                                           18.4
# 2009                                                           18.4
# 2008                                                           18.4
# 2007                                                           18.4
# 2006                                                           18.4
# 2005                                                           18.4
# 2004                                                           18.4
# 2003                                                           18.4
# 2002                                                           18.4
# 2001                                                           18.4
#
#                                                 4
# Plant Type Code                                 C
# RPS Eligible                                False
# Primary Fuel Type                            Coal
# Solar Thermal                               False
# Small Hydro                                 False
# CEC Plant ID                                C0007
# EIA Plant ID                                10373
# Plant Name         Hanford - Retired October 2011
# Unit                                        GEN 1
# State                                          CA
# County                                      Kings
# City                                      Hanford
# Start Date                             09/01/1990
# Retire Date                            10/18/2011
# 2014                                          NaN
# 2013                                          NaN
# 2012                                          NaN
# 2011                                          NaN
# 2010                                        24.0
# 2009                                        24.0
# 2008                                        24.0
# 2007                                        24.0
# 2006                                        24.0
# 2005                                        24.0
# 2004                                        24.0
# 2003                                        24.0
# 2002                                        24.0
# 2001                                        24.0

# %%
power_plants['Start Date'] = pd.to_datetime(power_plants['Start Date'])
power_plants['Start Date'].hist(bins=30);

# %% [markdown]
# ## Electricity by County:  CONSUMPTION

# %%
cnty_consumption = pd.read_csv('datasets/ElectricityByCounty.csv')
cnty_consumption.head()
# Out:
#       County Sector          2018   Total Usage
# 0    ALAMEDA  Total  10417.109747  10417.109747
# 1     ALPINE  Total     18.704208     18.704208
# 2     AMADOR  Total    300.519785    300.519785
# 3      BUTTE  Total   1479.210775   1479.210775
# 4  CALAVERAS  Total    332.445821    332.445821

# %% [markdown]
# ## Electricity Cost:  by Utility

# %% [markdown]
# The cost of electricity is dependent on a number of factors including the provider, the type of consumer (residential, commercial, industrial), and the demand tier (peak vs. off peak).  To simplify this, I will use the average cost by utility and assign values to each county.

# %% [markdown]
# <img src="images/CA_Electric_Investor_Owned_Utilities_IOUs.png" alt="Example" width="300" height="">

# %% [markdown]
# ### Utilities by County

# %%
util_by_cnty = pd.read_csv('datasets/utilities_by_county.csv')
util_by_cnty.head()
# Out:
#                    Count   Utiltity
# 0     Los Angeles County  SCE/LADWP
# 1       San Diego County      SDG&E
# 2          Orange County      SDG&E
# 3       Riverside County        SCE
# 4  San Bernardino County        SCE

# %%
util_by_cnty['Utiltity'].value_counts()
# Out:
# PG&E         39
# Other         7
# SCE           5
# SCE/LADWP     2
# SCE/PG&E      2
# SDG&E         2
# SMUD          1
# Name: Utiltity, dtype: int64

# %% [markdown]
# ### Forecasting
#
# An important element of this project is to predict future demand.  I will be looking at the changes in electricity cost over time as a factor in forecasting solar development demand.

# %%
util_cost = pd.read_csv('datasets/utility_cost.csv')
util_cost.head()
# Out:
#           Type  Year  PG&E  SCE  SDG&E  SMUD  LADWP  BUGL  PASA  IID
# 0  Residential  1977   4.0  4.2    4.8   2.0    4.4   4.4   4.4  4.4
# 1  Residential  1978   3.6  4.5    4.7   2.1    4.8   4.8   4.8  4.8
# 2  Residential  1979   4.0  4.6    5.4   2.2    5.4   5.4   5.4  5.4
# 3  Residential  1980   4.8  6.2    8.0   2.6    6.2   6.2   6.2  6.2
# 4  Residential  1981   6.1  6.7    9.0   3.0    6.5   6.5   6.5  6.5

# %%
res = util_cost[util_cost['Type'] == 'Residential']

plt.figure(figsize=(10,6))
plt.plot(res['Year'],res[['PG&E','SCE','SDG&E','SMUD','LADWP','BUGL','PASA','IID']])
plt.xlabel('Year')
plt.ylabel('Cents / kWhr')
plt.legend(['PG&E','SCE','SDG&E','SMUD','LADWP','BUGL','PASA','IID']);

# %% [markdown]
# ### County Population Change
#
# Census data from 2020 (pop) and growth percentage since 2010 (GrowthRate) by county (CTYNAME)

# %%
pop_cnty = pd.read_csv('datasets/county_census.csv')
pop_cnty.head()
# Out:
#                  CTYNAME       Pop  GrowthRate
# 0     Los Angeles County  10105518      2.8820
# 1       San Diego County   3343364      7.7356
# 2          Orange County   3185968      5.6160
# 3       Riverside County   2450758     11.3145
# 4  San Bernardino County   2171603      6.4037

# %% [markdown]
# ### Solar Rooftop Data
#
# This dataset comes from the National Renewable Energy Lab (NREL) and details potential development sites for rooftop solar production. I will use the zipcodes to drop them into counties to summarize the net solar potential by county.

# %%
solar = pd.read_csv('datasets/nrel_summary.csv')
solar[solar['State']=='CA'].head().T
# Out:
#                                                               4475  \
# Zip                                                          90001
# Zip Percentage                                                   1
# Region                                                  LosAngeles
# City                                                          -
# State                                                           CA
# Year                                                          2007
#  Total Building Count                                      11,232
#  Total Roof Area (sq meters)                            2,389,681
#  Total Potential Capacity with 10m2 minimum (kW)        174,729.90
#  Total potential energy generation with 10m2 mi...  263,135,800.00
#  Total Buildings in lidar - SMALL                        10,787.00
#  Total Area in lidar (sq meters) - SMALL              1,260,841.90
#  Buildings - SMALL with any size available area          10,783.00
#  Area (sq meters) - SMALL with any size availab...      638,300.38
#  Buildings - SMALL - with 10m2+ available area            9,955.00
#  Area (sq meters) - SMALL - with 10m2+ availabl...      495,309.37
#  Small building potential capacity with 10m2 mi...       74,349.60
#  Small building potential energy generation wit...  110,251,000.00
#  Total Buildings in lidar - MEDIUM                          327.00
#  Total Area in lidar (sq meters) - MEDIUM               332,732.91
#  Buildings - MEDIUM with any size available area            327.00
#  Area (sq meters) - MEDIUM with any size availa...      224,059.37
#  Buildings - MEDIUM with 10m2+ available area               327.00
#  Area (sq meters) - MEDIUM with 10m2+ available...      209,976.40
#  Medium building potential capacity with 10m2 m...       26,914.90
#  Medium building potential energy generation wi...   40,852,800.00
#  Total Buildings in lidar - LARGE                              118
#  Total Area in lidar (sq meters) - LARGE                796,106.23
#  Buildings - LARGE with any size available area                118
#  Area (sq meters) - LARGE with any size availab...      602,000.90
#  Buildings - LARGE - with 10m2+ available area                 118
#  Area (sq meters) - LARGE - with 10m2+ availabl...      580,569.87
#  Large building potential capacity with 10m2 mi...       73,465.40
#  Large building potential energy generation wit...  112,032,000.00
#  Average Building Footprint (sq meters)                     212.76
# % Buildings in SMALL category                                96.0%
# % Area in SMALL category                                     52.8%
# % Buildings in MEDIUM category                                2.9%
# % Area in MEDIUM category                                    13.9%
# % Buildings in LARGE category                                 1.1%
# % Area in LARGE category                                     33.3%
# % Buildings - SMALL                                         100.0%
# % Area - SMALL                                               50.6%
# % Buildings - SMALL - 10m2                                   92.3%
# % Area - SMALL - 10m2                                        39.3%
# % Buildings - MEDIUM                                        100.0%
# % Area - MEDIUM                                              67.3%
# % Buildings - MEDIUM - 10m2                                 100.0%
# % Area - MEDIUM - 10m2                                       63.1%
# % Buildings - LARGE                                         100.0%
# % Area - LARGE                                               75.6%
# % Buildings - LARGE - 10m2                                  100.0%
# % Area - LARGE - 10m2                                        72.9%
# ulocaledesc                                             City Large
# 2010_PopDens_SqMile                                        17130.3
# CensusRegion                                               Pacific
#
#                                                                4476  \
# Zip                                                           90002
# Zip Percentage                                                    1
# Region                                                   LosAngeles
# City                                                Los Angeles, CA
# State                                                            CA
# Year                                                           2007
#  Total Building Count                                       10,105
#  Total Roof Area (sq meters)                             1,467,885
#  Total Potential Capacity with 10m2 minimum (kW)          89,907.12
#  Total potential energy generation with 10m2 mi...   135,685,100.00
#  Total Buildings in lidar - SMALL                          9,946.00
#  Total Area in lidar (sq meters) - SMALL               1,197,371.13
#  Buildings - SMALL with any size available area            9,935.00
#  Area (sq meters) - SMALL with any size availab...       581,325.75
#  Buildings - SMALL - with 10m2+ available area             9,095.00
#  Area (sq meters) - SMALL - with 10m2+ availabl...       448,303.90
#  Small building potential capacity with 10m2 mi...        68,014.50
#  Small building potential energy generation wit...   102,050,000.00
#  Total Buildings in lidar - MEDIUM                           138.00
#  Total Area in lidar (sq meters) - MEDIUM                122,139.16
#  Buildings - MEDIUM with any size available area             138.00
#  Area (sq meters) - MEDIUM with any size availa...        75,311.15
#  Buildings - MEDIUM with 10m2+ available area                138.00
#  Area (sq meters) - MEDIUM with 10m2+ available...        69,917.52
#  Medium building potential capacity with 10m2 m...         9,096.92
#  Medium building potential energy generation wi...    13,893,200.00
#  Total Buildings in lidar - LARGE                                21
#  Total Area in lidar (sq meters) - LARGE                 148,374.26
#  Buildings - LARGE with any size available area                  21
#  Area (sq meters) - LARGE with any size availab...       112,135.75
#  Buildings - LARGE - with 10m2+ available area                   21
#  Area (sq meters) - LARGE - with 10m2+ availabl...       108,324.58
#  Large building potential capacity with 10m2 mi...        12,795.70
#  Large building potential energy generation wit...    19,741,900.00
#  Average Building Footprint (sq meters)                      145.26
# % Buildings in SMALL category                                 98.4%
# % Area in SMALL category                                      81.6%
# % Buildings in MEDIUM category                                 1.4%
# % Area in MEDIUM category                                      8.3%
# % Buildings in LARGE category                                  0.2%
# % Area in LARGE category                                      10.1%
# % Buildings - SMALL                                           99.9%
# % Area - SMALL                                                48.6%
# % Buildings - SMALL - 10m2                                    91.4%
# % Area - SMALL - 10m2                                         37.4%
# % Buildings - MEDIUM                                         100.0%
# % Area - MEDIUM                                               61.7%
# % Buildings - MEDIUM - 10m2                                  100.0%
# % Area - MEDIUM - 10m2                                        57.2%
# % Buildings - LARGE                                          100.0%
# % Area - LARGE                                                75.6%
# % Buildings - LARGE - 10m2                                   100.0%
# % Area - LARGE - 10m2                                         73.0%
# ulocaledesc                                              City Large
# 2010_PopDens_SqMile                                         16657.1
# CensusRegion                                                Pacific
#
#                                                                4477  \
# Zip                                                           90003
# Zip Percentage                                                    1
# Region                                                   LosAngeles
# City                                                Los Angeles, CA
# State                                                            CA
# Year                                                           2007
#  Total Building Count                                       13,014
#  Total Roof Area (sq meters)                             1,949,595
#  Total Potential Capacity with 10m2 minimum (kW)         125,856.60
#  Total potential energy generation with 10m2 mi...   186,517,200.00
#  Total Buildings in lidar - SMALL                         12,679.00
#  Total Area in lidar (sq meters) - SMALL               1,516,002.19
#  Buildings - SMALL with any size available area           12,670.00
#  Area (sq meters) - SMALL with any size availab...       768,715.59
#  Buildings - SMALL - with 10m2+ available area            11,733.00
#  Area (sq meters) - SMALL - with 10m2+ availabl...       601,930.25
#  Small building potential capacity with 10m2 mi...        91,949.80
#  Small building potential energy generation wit...   134,553,000.00
#  Total Buildings in lidar - MEDIUM                           301.00
#  Total Area in lidar (sq meters) - MEDIUM                271,801.85
#  Buildings - MEDIUM with any size available area             301.00
#  Area (sq meters) - MEDIUM with any size availa...       175,512.59
#  Buildings - MEDIUM with 10m2+ available area                301.00
#  Area (sq meters) - MEDIUM with 10m2+ available...       164,055.10
#  Medium building potential capacity with 10m2 m...        20,803.70
#  Medium building potential energy generation wi...    31,798,200.00
#  Total Buildings in lidar - LARGE                                34
#  Total Area in lidar (sq meters) - LARGE                 161,790.66
#  Buildings - LARGE with any size available area                  34
#  Area (sq meters) - LARGE with any size availab...       109,334.27
#  Buildings - LARGE - with 10m2+ available area                   34
#  Area (sq meters) - LARGE - with 10m2+ availabl...       104,351.41
#  Large building potential capacity with 10m2 mi...        13,103.10
#  Large building potential energy generation wit...    20,166,000.00
#  Average Building Footprint (sq meters)                      149.81
# % Buildings in SMALL category                                 97.4%
# % Area in SMALL category                                      77.8%
# % Buildings in MEDIUM category                                 2.3%
# % Area in MEDIUM category                                     13.9%
# % Buildings in LARGE category                                  0.3%
# % Area in LARGE category                                       8.3%
# % Buildings - SMALL                                           99.9%
# % Area - SMALL                                                50.7%
# % Buildings - SMALL - 10m2                                    92.5%
# % Area - SMALL - 10m2                                         39.7%
# % Buildings - MEDIUM                                         100.0%
# % Area - MEDIUM                                               64.6%
# % Buildings - MEDIUM - 10m2                                  100.0%
# % Area - MEDIUM - 10m2                                        60.4%
# % Buildings - LARGE                                          100.0%
# % Area - LARGE                                                67.6%
# % Buildings - LARGE - 10m2                                   100.0%
# % Area - LARGE - 10m2                                         64.5%
# ulocaledesc                                              City Large
# 2010_PopDens_SqMile                                         18905.1
# CensusRegion                                                Pacific
#
#                                                                4478  \
# Zip                                                           90004
# Zip Percentage                                                    1
# Region                                                   LosAngeles
# City                                                Los Angeles, CA
# State                                                            CA
# Year                                                           2007
#  Total Building Count                                        7,814
#  Total Roof Area (sq meters)                             1,945,381
#  Total Potential Capacity with 10m2 minimum (kW)         110,578.20
#  Total potential energy generation with 10m2 mi...   168,495,400.00
#  Total Buildings in lidar - SMALL                          7,150.00
#  Total Area in lidar (sq meters) - SMALL               1,249,772.06
#  Buildings - SMALL with any size available area            7,135.00
#  Area (sq meters) - SMALL with any size availab...       559,462.20
#  Buildings - SMALL - with 10m2+ available area             6,594.00
#  Area (sq meters) - SMALL - with 10m2+ availabl...       446,744.86
#  Small building potential capacity with 10m2 mi...        63,779.40
#  Small building potential energy generation wit...    96,390,400.00
#  Total Buildings in lidar - MEDIUM                           615.00
#  Total Area in lidar (sq meters) - MEDIUM                515,216.63
#  Buildings - MEDIUM with any size available area             615.00
#  Area (sq meters) - MEDIUM with any size availa...       300,294.19
#  Buildings - MEDIUM with 10m2+ available area                615.00
#  Area (sq meters) - MEDIUM with 10m2+ available...       274,633.86
#  Medium building potential capacity with 10m2 m...        33,728.90
#  Medium building potential energy generation wi...    51,879,600.00
#  Total Buildings in lidar - LARGE                                49
#  Total Area in lidar (sq meters) - LARGE                 180,392.45
#  Buildings - LARGE with any size available area                  49
#  Area (sq meters) - LARGE with any size availab...       118,922.31
#  Buildings - LARGE - with 10m2+ available area                   49
#  Area (sq meters) - LARGE - with 10m2+ availabl...       110,185.03
#  Large building potential capacity with 10m2 mi...        13,069.90
#  Large building potential energy generation wit...    20,225,400.00
#  Average Building Footprint (sq meters)                      248.96
# % Buildings in SMALL category                                 91.5%
# % Area in SMALL category                                      64.2%
# % Buildings in MEDIUM category                                 7.9%
# % Area in MEDIUM category                                     26.5%
# % Buildings in LARGE category                                  0.6%
# % Area in LARGE category                                       9.3%
# % Buildings - SMALL                                           99.8%
# % Area - SMALL                                                44.8%
# % Buildings - SMALL - 10m2                                    92.2%
# % Area - SMALL - 10m2                                         35.7%
# % Buildings - MEDIUM                                         100.0%
# % Area - MEDIUM                                               58.3%
# % Buildings - MEDIUM - 10m2                                  100.0%
# % Area - MEDIUM - 10m2                                        53.3%
# % Buildings - LARGE                                          100.0%
# % Area - LARGE                                                65.9%
# % Buildings - LARGE - 10m2                                   100.0%
# % Area - LARGE - 10m2                                         61.1%
# ulocaledesc                                              City Large
# 2010_PopDens_SqMile                                         20487.3
# CensusRegion                                                Pacific
#
#                                                                4479
# Zip                                                           90005
# Zip Percentage                                                    1
# Region                                                   LosAngeles
# City                                                Los Angeles, CA
# State                                                            CA
# Year                                                           2007
#  Total Building Count                                        2,084
#  Total Roof Area (sq meters)                               921,170
#  Total Potential Capacity with 10m2 minimum (kW)          53,108.70
#  Total potential energy generation with 10m2 mi...    81,634,900.00
#  Total Buildings in lidar - SMALL                          1,616.00
#  Total Area in lidar (sq meters) - SMALL                 309,133.57
#  Buildings - SMALL with any size available area            1,614.00
#  Area (sq meters) - SMALL with any size availab...       137,114.77
#  Buildings - SMALL - with 10m2+ available area             1,436.00
#  Area (sq meters) - SMALL - with 10m2+ availabl...       110,259.89
#  Small building potential capacity with 10m2 mi...        15,056.50
#  Small building potential energy generation wit...    22,822,000.00
#  Total Buildings in lidar - MEDIUM                           407.00
#  Total Area in lidar (sq meters) - MEDIUM                362,953.61
#  Buildings - MEDIUM with any size available area             407.00
#  Area (sq meters) - MEDIUM with any size availa...       208,041.69
#  Buildings - MEDIUM with 10m2+ available area                407.00
#  Area (sq meters) - MEDIUM with 10m2+ available...       189,537.22
#  Medium building potential capacity with 10m2 m...        22,792.20
#  Medium building potential energy generation wi...    35,198,900.00
#  Total Buildings in lidar - LARGE                                61
#  Total Area in lidar (sq meters) - LARGE                 249,083.17
#  Buildings - LARGE with any size available area                  61
#  Area (sq meters) - LARGE with any size availab...       138,775.57
#  Buildings - LARGE - with 10m2+ available area                   61
#  Area (sq meters) - LARGE - with 10m2+ availabl...       130,386.25
#  Large building potential capacity with 10m2 mi...        15,260.00
#  Large building potential energy generation wit...    23,614,000.00
#  Average Building Footprint (sq meters)                      442.02
# % Buildings in SMALL category                                 77.5%
# % Area in SMALL category                                      33.6%
# % Buildings in MEDIUM category                                19.5%
# % Area in MEDIUM category                                     39.4%
# % Buildings in LARGE category                                  2.9%
# % Area in LARGE category                                      27.0%
# % Buildings - SMALL                                           99.9%
# % Area - SMALL                                                44.4%
# % Buildings - SMALL - 10m2                                    88.9%
# % Area - SMALL - 10m2                                         35.7%
# % Buildings - MEDIUM                                         100.0%
# % Area - MEDIUM                                               57.3%
# % Buildings - MEDIUM - 10m2                                  100.0%
# % Area - MEDIUM - 10m2                                        52.2%
# % Buildings - LARGE                                          100.0%
# % Area - LARGE                                                55.7%
# % Buildings - LARGE - 10m2                                   100.0%
# % Area - LARGE - 10m2                                         52.3%
# ulocaledesc                                              City Large
# 2010_PopDens_SqMile                                         30756.5
# CensusRegion                                                Pacific

# %%
zip_cnty = pd.read_csv('datasets/zip_cnty.csv')
zip_cnty['County'].value_counts()
# Out:
# Los Angeles        525
# San Diego          189
# Orange             149
# Sacramento         133
# San Bernardino     121
# Santa Clara        108
# Riverside          101
# Fresno             100
# San Francisco       72
# Alameda             70
# Kern                69
# Contra Costa        51
# Sonoma              51
# Ventura             48
# San Joaquin         43
# Tulare              41
# Marin               41
# Santa Barbara       41
# San Mateo           40
# Humboldt            38
# San Luis Obispo     35
# Monterey            35
# Shasta              32
# El Dorado           30
# Placer              29
# Stanislaus          28
# Mendocino           28
# Butte               24
# Siskiyou            22
# Merced              22
# Santa Cruz          22
# Yolo                21
# Calaveras           21
# Imperial            17
# Tuolumne            16
# Nevada              16
# Solano              16
# Plumas              16
# Lassen              16
# Lake                15
# Madera              13
# Tehama              13
# Amador              13
# Trinity             12
# Yuba                12
# Napa                12
# Inyo                12
# Modoc               10
# Sutter              10
# Kings                9
# Mariposa             8
# Glenn                7
# Sierra               7
# Mono                 7
# Colusa               7
# Del Norte            6
# San Benito           5
# Alpine               2
# Name: County, dtype: int64

# %% [markdown]
# ## Final Product Goal

# %% [markdown]
# 1. County by county forecast of power production/demand and cost
# - derived from powerplant database and population forecast
# - factors in retirement rate of aging powerplants and assumed reduction in coal, gas, nuclear
# - assumes 2010-2020 population growth rates continue
# - assumes 2001-2014 electricity rates continue
#
# 2. Recommendation for which counties have the most viable market share for rooftop solar development
# - based on highest demand/production ratio
# - based on amount of fertile development space
# - OPTIONAL EXTENSION:  based on average weather (# of sunny days)

# %% [markdown]
# ### Data Sources
#
# - California energy production:  California Energy Commission
# https://ww2.energy.ca.gov/almanac/electricity_data/total_system_power.html
#
# - Powerplant data:  California Energy Commission
# https://energyarchive.ca.gov/
#
# - Energy consumption by county:  California Energy Commission
# http://www.ecdms.energy.ca.gov/elecbycounty.aspx
#
# - Electricity prices by utility: California Energy Commission
# https://energyarchive.ca.gov/
#
# - 2020 census data:  World Population Review
# https://worldpopulationreview.com/us-counties/ca/
#
# - Rooftop solar data:  National Renewable Energy Lab
# https://data.nrel.gov/submissions/121
